# %% [markdown]
# ## Limpiar cocheras que debieron caer

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import json
import datetime as dt
import re
from difflib import get_close_matches

pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)
print('Importadas ok')
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)
# Out:
# Importadas ok

# %% [markdown]
# ### Input BD

# %%
carpeta = "../data/raw/"
procesos_file = carpeta + "procesos.parquet"
unidades_file = carpeta + "unidades.parquet"
df_procesos_raw = pd.read_parquet(procesos_file)
df_unidades = pd.read_parquet(unidades_file)

df_procesos_raw.head(2)
# Out:
#   codigo_proyecto    nombre_proyecto tipo_unidad_principal codigo_unidad  \
# 0            EEUU  Edificio Urbanzen     departamento flat      EEUU-302
# 1            EEUU  Edificio Urbanzen     departamento flat     EEUU-1501
#
#    total_unidades codigo_unidades_asignadas  nombres_cliente  \
# 0               2                  EEUU-E19        Jan Henri
# 1               2                  EEUU-E26  Katherine Jessy
#
#     apellidos_cliente documento_cliente origen_proforma fecha_proforma  \
# 0              Larsen          48997555          manual     2025-09-16
# 1  Bendezú Delgadillo          45347923          manual     2024-03-19
#
#   codigo_proforma numero_contrato fecha_contrato modalidad_contrato moneda  \
# 0      2025-05785             NaN           None         Compromiso    PEN
# 1      2024-00497             NaN           None         Compromiso    PEN
#
#   tipo_cambio tipo_financiamiento                            banco  \
# 0    1.000000         hipotecario                              NaN
# 1    1.000000              ahorro  Banco de Crédito del Perú (BCP)
#
#     situacion_legal documento_representante            nombres_usuario  \
# 0          Conyugal                17896123            Yomira  Pacheco
# 1  Propietario Solo                     NaN  Nelly Román Villavicencio
#
#    username precio_base_proforma descuento_venta precio_venta  \
# 0  ypacheco            712460.00        77460.00    635000.00
# 1    nroman            659509.20        72744.51    586764.69
#
#   aprobador_descuento   nombre premios fecha_inicio   fecha_fin  \
# 0           ldelsolar  Entrega    None   2026-01-26  2026-01-30
# 1         evillanueva  Entrega    None   2026-03-17  2026-03-17
#
#   fecha_expiracion fecha_impresion_contrato        nombre_flujo  estado  \
# 0             None                     None  Proceso de entrega  Activo
# 1             None                     None  Proceso de entrega  Activo
#
#    completado total_pagado total_pendiente fecha_analisis fecha_nif  \
# 0  Completado         0.00            0.00     2026-01-30      None
# 1  Completado         0.00            0.00     2026-03-17      None
#
#   estado_nif utm_source utm_medium utm_campaign utm_term utm_content  \
# 0        NaN       None       None         None     None        None
# 1        NaN       None       None         None     None        None
#
#   documento_conyuge documento_copropietarios flujo_anulacion fecha_anulacion  \
# 0          17896123                      NaN             NaN            None
# 1               NaN                      NaN             NaN            None
#
#   codigo_externo_venta  id     tipo fecha_actualizacion codigo_externo_minuta  \
# 0                 None  21  ENTREGA          2026-01-30                  None
# 1                 None  68  ENTREGA          2026-03-17                  None
#
#   flujo_error momento_caida tipo_cronograma estado_contrato devolucion  \
# 0       False           NaN             NaN             NaN       0.00
# 1       False           NaN             NaN             NaN       0.00
#
#   fecha_devolucion  excedente observacion_devolucion motivo_caida  \
# 0             None        0.0                    NaN         None
# 1             None        0.0                    NaN         None
#
#   nombres_usuario_aprobador username_aprobador  cliente_id  \
# 0                       NaN                NaN      121739
# 1                       NaN                NaN       43624
#
#          usuario_creador username_creador usuario_separacion  \
# 0  JOSUE QUIROGA NAVARRO         jquiroga                NaN
# 1  JOSUE QUIROGA NAVARRO         jquiroga                NaN
#
#   codigo_externo_entrega fecha_minuta  proforma_id penalidad  \
# 0                   None         None        26094      0.00
# 1                   None         None        16905      0.00
#
#   proceso_anulacion codigo_externo_anulacion_venta terminado  \
# 0        al iniciar                           None      None
# 1        al iniciar                           None      None
#
#          paso_actual estado_personalizado
# 0  Proceso Terminado                 None
# 1  Proceso Terminado                 None

# %% [markdown]
# # Helpers

# %% [markdown]
# ### Filtrar df = por columnas con diccionario

# %%
import pandas as pd


def filtrar_df(df, condiciones, mostrar_resumen=True):
    cantidad_antes = len(df)

    mascara = pd.Series(True, index=df.index)

    for columna, condicion in condiciones.items():

        if columna not in df.columns:
            raise KeyError(
                f"La columna '{columna}' no existe en el DataFrame."
            )

        serie = df[columna]

        # Nulos, textos vacíos o textos compuestos solo por espacios
        es_vacio = (
            serie.isna()
            | serie.astype("string")
                   .str.strip()
                   .eq("")
                   .fillna(False)
        )

        # Condiciones con operadores
        if isinstance(condicion, dict):

            operador = condicion.get("op")

            if operador == "vacio":
                mascara &= es_vacio

            elif operador == "no_vacio":
                mascara &= ~es_vacio

            elif operador == "igual":
                valor = condicion.get("valor")
                mascara &= serie.eq(valor)

            elif operador == "en":
                valores = condicion.get("valores", [])
                mascara &= serie.isin(valores)

            else:
                raise ValueError(
                    f"Operador '{operador}' no reconocido "
                    f"para la columna '{columna}'."
                )

        # Si recibe una lista, actúa como IN
        elif isinstance(condicion, (list, tuple, set)):
            mascara &= serie.isin(condicion)

        # Si recibe un valor normal, actúa como igualdad
        else:
            mascara &= serie.eq(condicion)

    resultado = df.loc[mascara].copy()

    cantidad_despues = len(resultado)
    cantidad_eliminada = cantidad_antes - cantidad_despues

    porcentaje_conservado = (
        cantidad_despues / cantidad_antes * 100
        if cantidad_antes > 0
        else 0
    )

    if mostrar_resumen:
        print("Resumen del filtro")
        print(f"Filas antes:       {cantidad_antes:,}")
        print(f"Filas después:     {cantidad_despues:,}")
        print(f"Filas descartadas: {cantidad_eliminada:,}")
        print(f"Porcentaje conservado: {porcentaje_conservado:.2f}%")

    return resultado

# %% [markdown]
# ### La unidad homologada

# %%
def añadir_unidad_general(tipo):
    if tipo.startswith('departamento'):
        x= 'departamento'
    elif tipo.startswith('estacionamiento'):
        x= 'estacionamiento'
    elif tipo.startswith('depósito'):
        x= 'deposito'
    elif tipo.startswith('local comercial'):
        x= 'local comercial'
    else:
        x='otro'

    return x

# %% [markdown]
# # Condiciones

# %%
condiciones_de_cocheras_sindepa = {
                'estado': 'Activo',
                "codigo_proyecto": ["TZ", "NP", "EEUU", "MD", "MA", "SL", "GY", "FX", "MT", "CP"],
                "tipo_unidad_homologado": 'estacionamiento',
                "codigo_unidades_asignadas": {"op": "vacio"}
}

# %% [markdown]
# # BD DE PROCESOS

# %% [markdown]
# ## PROCESO DE COCHERAS SIN DEPAS

# %% [markdown]
# ### 1) Filtrar solo proyectos relevantes

# %%
print(f'Procesos Totales: {df_procesos_raw.shape[0]}')
df_procesos = df_procesos_raw.copy()
######################################################
df_procesos['tipo_unidad_homologado'] = df_procesos['tipo_unidad_principal'].apply(añadir_unidad_general)
print('Añadido unidad homologada.')
######################################################
print(df_procesos[['tipo_unidad_homologado', 'tipo_unidad_principal', 'estado']].value_counts())
df_procesos['tipo_unidad_homologado'].value_counts().plot(kind='barh', title = 'Unidades de proyectos activos')

######################################################
df_procesos_cocheras = filtrar_df(df_procesos, condiciones_de_cocheras_sindepa)
print('BD de procesos filtrada por cocheras sin depa')
######################################################
print(df_procesos_cocheras['codigo_proyecto'].value_counts())
df_procesos_cocheras.to_excel('BD de cocheras sin unidades.xlsx', index=False)
df_procesos_cocheras['nombre_proyecto'].value_counts().sort_values().plot(
    kind='barh',
    figsize=(16, 4),
    title='Cantidad de procesos por proyecto'
)
# Out:
# Procesos Totales: 4806
# Añadido unidad homologada.
# tipo_unidad_homologado  tipo_unidad_principal         estado
# departamento            departamento flat             Activo      3264
# estacionamiento         estacionamiento simple        Activo       662
# departamento            departamento flat             Inactivo     480
# estacionamiento         estacionamiento con depósito  Activo       132
# deposito                depósito                      Activo        99
# departamento            departamento duplex           Activo        69
# estacionamiento         estacionamiento simple        Inactivo      45
#                         estacionamiento con depósito  Inactivo      20
# departamento            departamento duplex           Inactivo      18
# estacionamiento         estacionamiento doble         Activo         7
# deposito                depósito                      Inactivo       7
# local comercial         local comercial               Activo         3
# Name: count, dtype: int64
# Resumen del filtro
# Filas antes:       4,806
# Filas después:     316
# Filas descartadas: 4,490
# Porcentaje conservado: 6.58%
# BD de procesos filtrada por cocheras sin depa
# codigo_proyecto
# TZ      74
# EEUU    33
# NP      32
# MD      31
# MA      30
# CP      28
# SL      25
# FX      22
# MT      21
# GY      20
# Name: count, dtype: int64
# <Axes: title={'center': 'Cantidad de procesos por proyecto'}, ylabel='nombre_proyecto'>

# %% [markdown]
# # PROPIETARIOS DE DEPARTAMENTOS

# %%
condiciones = {
                'estado': 'Activo',
                "tipo_unidad_homologado": 'departamento'
}
df_procesos_depas = filtrar_df(df_procesos_raw, condiciones)

print(df_procesos_depas['estado'].value_counts())
df_procesos_depas = filtrar_df(df_procesos, condiciones)

df_procesos_depas.sample(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 5
#       1 condiciones = {
#       2                 'estado': 'Activo',
#       3                 "tipo_unidad_homologado": 'departamento'
#       4 }
# ----> 5 df_procesos_depas = filtrar_df(df_procesos_raw, condiciones)
#       6
#       7 print(df_procesos_depas['estado'].value_counts())
#       8 df_procesos_depas = filtrar_df(df_procesos, condiciones)
#
# Cell In[32], line 12, in filtrar_df(df, condiciones, mostrar_resumen)
#       8
#       9     for columna, condicion in condiciones.items():
#      10
#      11         if columna not in df.columns:
# ---> 12             raise KeyError(
#      13                 f"La columna '{columna}' no existe en el DataFrame."
#      14             )
#      15
#
# KeyError: "La columna 'tipo_unidad_homologado' no existe en el DataFrame."
